# %%
# Out:
# 📊 Loading annotation files...

# %%
# Out:
#   ✅ NHTyp1.xml: 310 images with expert scores, 345 total images
#   ✅ NHTyp2.xml: 327 images with expert scores, 353 total images
#   ✅ NHTyp3.xml: 394 images with expert scores, 411 total images
#   ✅ NHTyp4.xml: 347 images with expert scores, 380 total images
#   ✅ NHTyp5.xml: 308 images with expert scores, 367 total images
#
# 📈 Total images with expert scores: 1686
# 📈 Total images in annotation files: 1856

# %%
# Out:
# 📊 Dataset Overview:
# Total images in annotation files: 1856
# Total images with expert scores: 1686
# Images missing expert scores: 170
# Expert score coverage: 90.84%
#
# Score distribution:
# score
# 1    211
# 2    544
# 3    607
# 4    283
# 5     41
# Name: count, dtype: int64
#   dataset image_id                                         image_name  score
# 0  NHTyp1        0  NHTyp1/ATT10035_PropertyConditionAssessment_im...      1
# 1  NHTyp1        1  NHTyp1/ATT10037_PropertyConditionAssessment_im...      1
# 2  NHTyp1        2  NHTyp1/ATT10050_PropertyConditionAssessment_im...      1
# 3  NHTyp1        3  NHTyp1/ATT10051_PropertyConditionAssessment_im...      1
# 4  NHTyp1        4  NHTyp1/ATT10074_PropertyConditionAssessment_im...      3

# %%
# Out:
# 📊 Image Coverage Analysis:
# ...
# Total Images in Folders: 1856
# Total Annotated in XML: 1856
# Total Covered: 1856
# Total Uncovered: 0
# Overall Coverage: 100.00%
#
# ✅ All images are covered in annotation files!

# %%
# Out:
# 📊 Annotation Completeness:
# ...
# Total Images in XML: 1856
# Images with Expert Score: 1686 (90.84%)
# Images without Expert Score: 170 (9.16%)
#
# 📊 Good/Bad Label Distribution:
# --------------------------------------------------------------------------------
#   Images with 'good' label only: 1318
#   Images with 'bad' label only: 536
#   Images with both 'good' and 'bad': 1
#   Images with neither label: 1
#   Good/Bad Coverage: 99.95%
#
# 📊 Component Scores:
# --------------------------------------------------------------------------------
#   Drive-way: 20 annotations
#     Score 1: 1 (5.0%)
#     Score 3: 2 (10.0%)
#     Score 4: 13 (65.0%)
#     Score 5: 4 (20.0%)
#   Siding: 34 annotations
#     Score 1: 1 (2.9%)
#     Score 3: 8 (23.5%)
#     Score 4: 13 (38.2%)
#     Score 5: 12 (35.3%)
#   Roof: 25 annotations
#     Score 1: 1 (4.0%)
#     Score 3: 2 (8.0%)
#     Score 4: 12 (48.0%)
#     Score 5: 10 (40.0%)
#   Window: 37 annotations
#     Score 1: 1 (2.7%)
# ...

# %%
# Out:
# 📊 3-Bucket Distribution:
# bucket
# Healthy (1-2)      755
# In-Between (3)     607
# Unhealthy (4-5)    324
# Name: count, dtype: int64
#
# Percentages:
# bucket
# Healthy (1-2)      44.78
# In-Between (3)     36.00
# Unhealthy (4-5)    19.22
# Name: count, dtype: float64

# %%
# Out:
# ✅ Visualizations created!

# %%
# Out:
# ...
# SUMMARY STATISTICS
# ...
#
# 📊 Dataset Overview:
# --------------------------------------------------------------------------------
#   Total Images in Folders: 1856
#   Total Images in XML Files: 1856
#   Images with Expert Scores: 1686
#   Expert Score Coverage: 90.84%
#
# 📊 5-Point Scale Distribution:
# --------------------------------------------------------------------------------
#   Score 1 (1 - Very Healthy):  211 images (12.51%)
#   Score 2 (2 - Healthy House):  544 images (32.27%)
#   Score 3 (3 - In-Between):  607 images (36.00%)
#   Score 4 (4 - Slipping):  283 images (16.79%)
#   Score 5 (5 - Unhealthy House):   41 images ( 2.43%)
#
#   Total Scored Images: 1686
#   Average Score: 2.64
#   Median Score: 3.00
#
# 📊 3-Bucket Distribution:
# --------------------------------------------------------------------------------
#   Healthy (1-2):  755 images (44.78%)
#   In-Between (3):  607 images (36.00%)
#   Unhealthy (4-5):  324 images (19.22%)
#
# 📊 Annotation Quality:
# ...

# %%
# Out:
# ...
# FINAL SUMMARY
# ...
#
# ✅ Dataset Coverage:
#    • Total Images: 1856
#    • Image Coverage: 100.0%
#    • Expert Score Coverage: 90.8%
#
# ✅ Score Analysis:
#    • Total Scored Images: 1686
#    • Average Score: 2.64
#    • Median Score: 3.00
#
# ✅ 3-Bucket Classification:
#    • Healthy (Scores 1-2): 755 images (44.8%)
#    • In-Between (Score 3): 607 images (36.0%)
#    • Unhealthy (Scores 4-5): 324 images (19.2%)
#
# ✅ Data Quality:
#    • Good/Bad Label Coverage: 99.9%
#    • No data quality issues detected
#
# ...
